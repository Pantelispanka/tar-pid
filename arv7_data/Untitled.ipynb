# %%
import nglview
import matplotlib as mpl
import matplotlib.pyplot as plt
import pyKVFinder
import os

# To reproduce this files, run:
# pyKVFinder ../../tests/data/1FMO.pdb --hydropathy --depth

# Fill this information with your own data
results_file = './data/1FMO.KVFinder.results.toml'
pdb = './data/1FMO.pdb'
cavities = './data/1FMO.KVFinder.output.pdb'
hydropathy = './data/1FMO.EisenbergWeiss.pdb'  # If not calculated, set to None


results_file = './data/0_a.KVFinder.results.toml'
pdb = './data/0_a.pdb'
pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/data/0_a.pdb"
cavities = './data/0_a.KVFinder.output.pdb'
hydropathy = './data/0_a.EisenbergWeiss.pdb'  # If not calculated, set to None

import toml

        # Load KVFinder results
results = toml.load(results_file)

        # Define function to rotate object
def rotate_view(view, x=0, y=0, z=0, degrees=True):
    radians = 1
    if degrees: radians = 3.1416 / 180
    view.control.spin([1, 0, 0], x * radians)
    view.control.spin([0, 1, 0], y * radians)
    view.control.spin([0, 0, 1], z * radians)

# Visualize cavity (blue) and surface (red) points

# Create NGL Viewer widget
view = nglview.NGLWidget()

# Add protein
p1 = view.add_component(pdb)
p1.clear()
p1.add_cartoon(color='grey')
# Uncomment to add transparency to cartoon representation and comment the line above
# p1.add_cartoon(color='grey', opacity=0.5)

# Add cavities
p2 = view.add_component(cavities)
p2.clear()
p2.add_point(selection='.HA', color='red')
p2.add_point(selection='.H', color='blue')

        # Show volume and area
print('Volume: ', end='')
print(results['RESULTS']['VOLUME'])
print('Area: ', end='')
print(results['RESULTS']['AREA'])

        # Show
view

# %%
import nglview
import matplotlib as mpl
import matplotlib.pyplot as plt
import pyKVFinder
import os
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/docking/test/data/AF-Q7Q7P1-F1-model_v4.pdb"
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/a_syn_data/182_a.pdb"
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/a_syn_data/116_a.pdb"
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/a_syn_data/15_a.pdb"
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/a_syn_data/129_a.pdb"
pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/a_syn_data/117_a.pdb"

pdb = "./out.pdb"
results = pyKVFinder.run_workflow(pdb, include_depth=True, include_hydropathy=True, hydrophobicity_scale='EisenbergWeiss')

print(results.avg_hydropathy)

results.export_all(fn='./results.toml', output='./cavity.pdb', include_frequencies_pdf=True, pdf='./barplots.pdf')



results_file = './out_results.toml'
cavities = './out_cavity.pdb'

# results_file = './results.toml'
# cavities = './cavity.pdb'



import toml

        # Load KVFinder results
results = toml.load(results_file)

        # Define function to rotate object
def rotate_view(view, x=0, y=0, z=0, degrees=True):
    radians = 1
    if degrees: radians = 3.1416 / 180
    view.control.spin([1, 0, 0], x * radians)
    view.control.spin([0, 1, 0], y * radians)
    view.control.spin([0, 0, 1], z * radians)

# Visualize cavity (blue) and surface (red) points

# Create NGL Viewer widget
view = nglview.NGLWidget()

# Add protein
p1 = view.add_component(pdb)
p1.clear()
p1.add_cartoon(color='grey')
# Uncomment to add transparency to cartoon representation and comment the line above
# p1.add_cartoon(color='grey', opacity=0.5)

# Add cavities
p2 = view.add_component(cavities)
p2.clear()
p2.add_point(selection='.HA', color='red')
p2.add_point(selection='.H', color='blue')

        # Show volume and area
print('Volume: ', end='')
print(results['RESULTS']['VOLUME'])
print('Area: ', end='')
print(results['RESULTS']['AREA'])

        # Show
view
# Out:
# {'KAA': 0.16, 'KAB': 0.47, 'KAC': -0.45, 'KAD': -0.46, 'KAE': -0.58, 'KAF': 0.08, 'KAG': 0.01, 'KAH': 0.69, 'KAI': -0.17, 'KAJ': -0.16, 'KAK': -0.43, 'KAL': 0.69, 'KAM': -0.55, 'KAN': -0.37, 'KAO': -0.24, 'KAP': -0.65, 'KAQ': -0.56, 'KAR': 0.16, 'KAS': -0.24, 'KAT': 0.2, 'KAU': -0.33, 'KAV': -0.72, 'KAW': -0.17, 'KAX': -0.08, 'KAY': 0.63, 'KAZ': 0.04, 'KBA': 0.24, 'KBB': -0.67, 'KBC': -0.25, 'KBD': -0.52, 'KBE': -0.32, 'KBF': 1.0, 'KBG': -0.09, 'KBH': 0.51, 'KBI': 0.05, 'KBJ': -0.57, 'EisenbergWeiss': [-1.42, 2.6]}
# Volume: {'KAA': 22.9, 'KAB': 85.97, 'KAC': 19.87, 'KAD': 103.68, 'KAE': 10.15, 'KAF': 36.07, 'KAG': 423.79, 'KAH': 150.55, 'KAI': 18.79, 'KAJ': 79.49, 'KAK': 7.56, 'KAL': 34.34, 'KAM': 101.3, 'KAN': 183.38, 'KAO': 30.24, 'KAP': 94.61, 'KAQ': 5.4, 'KAR': 655.99, 'KAS': 62.64, 'KAT': 1123.85, 'KAU': 10.58, 'KAV': 7.56, 'KAW': 16.42, 'KAX': 575.86, 'KAY': 20.74, 'KAZ': 280.58, 'KBA': 50.33, 'KBB': 5.83, 'KBC': 12.96, 'KBD': 10.58, 'KBE': 6.48, 'KBF': 50.33, 'KBG': 328.1, 'KBH': 5.83, 'KBI': 23.33, 'KBJ': 22.25}
# Area: {'KAA': 44.08, 'KAB': 105.68, 'KAC': 39.6, 'KAD': 109.78, 'KAE': 17.8, 'KAF': 57.23, 'KAG': 333.04, 'KAH': 117.02, 'KAI': 27.35, 'KAJ': 73.27, 'KAK': 15.76, 'KAL': 34.33, 'KAM': 123.99, 'KAN': 92.29, 'KAO': 38.24, 'KAP': 82.95, 'KAQ': 12.44, 'KAR': 520.64, 'KAS': 43.76, 'KAT': 896.94, 'KAU': 9.33, 'KAV': 15.64, 'KAW': 21.55, 'KAX': 543.95, 'KAY': 27.55, 'KAZ': 275.91, 'KBA': 70.69, 'KBB': 14.65, 'KBC': 11.09, 'KBD': 18.51, 'KBE': 15.41, 'KBF': 56.85, 'KBG': 234.47, 'KBH': 15.63, 'KBI': 33.91, 'KBJ': 28.29}
# NGLWidget()

# %%
import nglview
import matplotlib as mpl
import matplotlib.pyplot as plt
import pyKVFinder
import os
# pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/AF-A0A626M381-F1-model_v4.pdb"
pdb = "/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/data/0_a.pdb"
results = pyKVFinder.run_workflow(pdb, include_depth=True, include_hydropathy=True, hydrophobicity_scale='EisenbergWeiss')

print(results.avg_hydropathy)

results.export_all(fn='/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/results.toml', output='/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/cavity.pdb', include_frequencies_pdf=True, pdf='/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/barplots.pdf')


results_file = '/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/results.toml'
cavities = '/Users/pantelispanka/miniconda3/envs/docking-examples/cavity_finder/test/salmonela/cavity.pdb'



import toml

        # Load KVFinder results
results = toml.load(results_file)

        # Define function to rotate object
def rotate_view(view, x=0, y=0, z=0, degrees=True):
    radians = 1
    if degrees: radians = 3.1416 / 180
    view.control.spin([1, 0, 0], x * radians)
    view.control.spin([0, 1, 0], y * radians)
    view.control.spin([0, 0, 1], z * radians)

# Visualize cavity (blue) and surface (red) points

# Create NGL Viewer widget
view = nglview.NGLWidget()

# Add protein
p1 = view.add_component(pdb)
p1.clear()
p1.add_cartoon(color='grey')
# Uncomment to add transparency to cartoon representation and comment the line above
# p1.add_cartoon(color='grey', opacity=0.5)

# Add cavities
p2 = view.add_component(cavities)
p2.clear()
p2.add_point(selection='.HA', color='red')
p2.add_point(selection='.H', color='blue')

        # Show volume and area
print('Volume: ', end='')
print(results['RESULTS']['VOLUME'])
print('Area: ', end='')
print(results['RESULTS']['AREA'])

        # Show
view
